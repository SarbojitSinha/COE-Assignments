# %% [markdown]
# <a href="https://colab.research.google.com/github/SarbojitSinha/COE-Assignments/blob/main/Assignment10_(COE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/vibrant-colorful-and-modern-wallpaper-a-3d-rendering_9620565.jpg!w700wp')

# %%
image
# Out:
# array([[[ 31,  67, 109],
#         [ 29,  66, 105],
#         [ 26,  61,  99],
#         ...,
#         [ 45,  49,  37],
#         [ 48,  52,  40],
#         [ 49,  53,  41]],
#
#        [[ 31,  67, 109],
#         [ 29,  66, 105],
#         [ 26,  61,  99],
#         ...,
#         [ 45,  49,  37],
#         [ 48,  52,  40],
#         [ 48,  52,  40]],
#
#        [[ 29,  68, 108],
#         [ 29,  66, 105],
#         [ 26,  62,  97],
#         ...,
#         [ 44,  48,  36],
#         [ 47,  51,  39],
#         [ 48,  52,  40]],
#
#        ...,
#
#        [[ 27,  23,   7],
#         [ 27,  23,   7],
#         [ 27,  23,   7],
#         ...,
#         [ 25,  25, 112],
#         [ 15,  15, 101],
#         [  5,   5,  94]],
#
#        [[ 27,  23,   7],
#         [ 27,  23,   7],
#         [ 27,  23,   7],
#         ...,
#         [ 27,  27, 109],
#         [ 34,  33, 117],
#         [ 27,  25, 112]],
#
#        [[ 27,  23,   7],
#         [ 27,  23,   7],
#         [ 27,  23,   7],
# ...

# %%
#Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
#Split the image into its RGB channels
r,g,b = cv2.split(image_rgb)

# %%
#Calculate the histograms of the RGB channels
hist_r = cv2.calcHist([r], [0], None, [256], [0, 256])
hist_g = cv2.calcHist([g], [0], None, [256], [0, 256])
hist_b = cv2.calcHist([b], [0], None, [256], [0, 256])

# %%
# Plot the histograms
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 3, 1)
plt.plot(hist_r, color='red')
plt.title('Red Channel Histogram')
plt.xlabel('Intensity')
plt.ylabel('Frequency')
plt.xlim([0, 256])
# Out:
# (0.0, 256.0)

# %%
plt.subplot(1, 3, 2)
plt.plot(hist_g, color='green')
plt.title('Green Channel Histogram')
plt.xlabel('Intensity')
plt.ylabel('Frequency')
plt.xlim([0, 256])
# Out:
# (0.0, 256.0)

# %%
plt.subplot(1, 3, 3)
plt.plot(hist_b, color='blue')
plt.title('Blue Channel Histogram')
plt.xlabel('Intensity')
plt.ylabel('Frequency')
plt.xlim([0, 256])
# Out:
# (0.0, 256.0)
